# %% [markdown]
# ## Building a GPT
#
# Companion notebook to the [Zero To Hero](https://karpathy.ai/zero-to-hero.html) video on GPT.

# %%
# We always start with a dataset to train on. Let's download the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2025-08-15 17:29:32--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.03s
#
# 2025-08-15 17:29:32 (34.1 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  1115394

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

print(encode("hii there"))
print(decode(encode("hii there")))
# Out:
# [46, 47, 47, 1, 58, 46, 43, 56, 43]
# hii there

# %%
# let's now encode the entire text dataset and store it into a torch.Tensor
import torch # we use PyTorch: https://pytorch.org
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000]) # the 1000 characters we looked at earier will to the GPT look like this
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59,  1, 39, 56, 43,  1, 39, 50, 50,
#          1, 56, 43, 57, 53, 50, 60, 43, 42,  1, 56, 39, 58, 46, 43, 56,  1, 58,
#         53,  1, 42, 47, 43,  1, 58, 46, 39, 52,  1, 58, 53,  1, 44, 39, 51, 47,
#         57, 46, 12,  0,  0, 13, 50, 50, 10,  0, 30, 43, 57, 53, 50, 60, 43, 42,
#          8,  1, 56, 43, 57, 53, 50, 60, 43, 42,  8,  0,  0, 18, 47, 56, 57, 58,
#          1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 18, 47, 56, 57, 58,  6,  1, 63,
#         53, 59,  1, 49, 52, 53, 61,  1, 15, 39, 47, 59, 57,  1, 25, 39, 56, 41,
#         47, 59, 57,  1, 47, 57,  1, 41, 46, 47, 43, 44,  1, 43, 52, 43, 51, 63,
#          1, 58, 53,  1, 58, 46, 43,  1, 54, 43, 53, 54, 50, 43,  8,  0,  0, 13,
#         50, 50, 10,  0, 35, 43,  1, 49, 52, 53, 61,  5, 58,  6,  1, 61, 43,  1,
#         49, 52, 53, 61,  5, 58,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47, 58,
#         47, 64, 43, 52, 10,  0, 24, 43, 58,  1, 59, 57,  1, 49, 47, 50, 50,  1,
#         46, 47, 51,  6,  1, 39, 52, 42,  1, 61, 43,  5, 50, 50,  1, 46, 39, 60,
#         43,  1, 41, 53, 56, 52,  1, 39, 58,  1, 53, 59, 56,  1, 53, 61, 52,  1,
#         54, 56, 47, 41, 43,  8,  0, 21, 57,  5, 58,  1, 39,  1, 60, 43, 56, 42,
#         47, 41, 58, 12,  0,  0, 13, 50, 50, 10,  0, 26, 53,  1, 51, 53, 56, 43,
#          1, 58, 39, 50, 49, 47, 52, 45,  1, 53, 52,  5, 58, 11,  1, 50, 43, 58,
#          1, 47, 58,  1, 40, 43,  1, 42, 53, 52, 43, 10,  1, 39, 61, 39, 63,  6,
#          1, 39, 61, 39, 63,  2,  0,  0, 31, 43, 41, 53, 52, 42,  1, 15, 47, 58,
#         47, 64, 43, 52, 10,  0, 27, 52, 43,  1, 61, 53, 56, 42,  6,  1, 45, 53,
#         53, 42,  1, 41, 47, 58, 47, 64, 43, 52, 57,  8,  0,  0, 18, 47, 56, 57,
#         58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 35, 43,  1, 39, 56, 43,  1,
#         39, 41, 41, 53, 59, 52, 58, 43, 42,  1, 54, 53, 53, 56,  1, 41, 47, 58,
#         47, 64, 43, 52, 57,  6,  1, 58, 46, 43,  1, 54, 39, 58, 56, 47, 41, 47,
#         39, 52, 57,  1, 45, 53, 53, 42,  8,  0, 35, 46, 39, 58,  1, 39, 59, 58,
#         46, 53, 56, 47, 58, 63,  1, 57, 59, 56, 44, 43, 47, 58, 57,  1, 53, 52,
#          1, 61, 53, 59, 50, 42,  1, 56, 43, 50, 47, 43, 60, 43,  1, 59, 57, 10,
#          1, 47, 44,  1, 58, 46, 43, 63,  0, 61, 53, 59, 50, 42,  1, 63, 47, 43,
#         50, 42,  1, 59, 57,  1, 40, 59, 58,  1, 58, 46, 43,  1, 57, 59, 54, 43,
#         56, 44, 50, 59, 47, 58, 63,  6,  1, 61, 46, 47, 50, 43,  1, 47, 58,  1,
#         61, 43, 56, 43,  0, 61, 46, 53, 50, 43, 57, 53, 51, 43,  6,  1, 61, 43,
#          1, 51, 47, 45, 46, 58,  1, 45, 59, 43, 57, 57,  1, 58, 46, 43, 63,  1,
#         56, 43, 50, 47, 43, 60, 43, 42,  1, 59, 57,  1, 46, 59, 51, 39, 52, 43,
#         50, 63, 11,  0, 40, 59, 58,  1, 58, 46, 43, 63,  1, 58, 46, 47, 52, 49,
#          1, 61, 43,  1, 39, 56, 43,  1, 58, 53, 53,  1, 42, 43, 39, 56, 10,  1,
#         58, 46, 43,  1, 50, 43, 39, 52, 52, 43, 57, 57,  1, 58, 46, 39, 58,  0,
#         39, 44, 44, 50, 47, 41, 58, 57,  1, 59, 57,  6,  1, 58, 46, 43,  1, 53,
#         40, 48, 43, 41, 58,  1, 53, 44,  1, 53, 59, 56,  1, 51, 47, 57, 43, 56,
#         63,  6,  1, 47, 57,  1, 39, 57,  1, 39, 52,  0, 47, 52, 60, 43, 52, 58,
#         53, 56, 63,  1, 58, 53,  1, 54, 39, 56, 58, 47, 41, 59, 50, 39, 56, 47,
#         57, 43,  1, 58, 46, 43, 47, 56,  1, 39, 40, 59, 52, 42, 39, 52, 41, 43,
#         11,  1, 53, 59, 56,  0, 57, 59, 44, 44, 43, 56, 39, 52, 41, 43,  1, 47,
#         57,  1, 39,  1, 45, 39, 47, 52,  1, 58, 53,  1, 58, 46, 43, 51,  1, 24,
#         43, 58,  1, 59, 57,  1, 56, 43, 60, 43, 52, 45, 43,  1, 58, 46, 47, 57,
#          1, 61, 47, 58, 46,  0, 53, 59, 56,  1, 54, 47, 49, 43, 57,  6,  1, 43,
#         56, 43,  1, 61, 43,  1, 40, 43, 41, 53, 51, 43,  1, 56, 39, 49, 43, 57,
#         10,  1, 44, 53, 56,  1, 58, 46, 43,  1, 45, 53, 42, 57,  1, 49, 52, 53,
#         61,  1, 21,  0, 57, 54, 43, 39, 49,  1, 58, 46, 47, 57,  1, 47, 52,  1,
#         46, 59, 52, 45, 43, 56,  1, 44, 53, 56,  1, 40, 56, 43, 39, 42,  6,  1,
#         52, 53, 58,  1, 47, 52,  1, 58, 46, 47, 56, 57, 58,  1, 44, 53, 56,  1,
#         56, 43, 60, 43, 52, 45, 43,  8,  0,  0])

# %%
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([18]) the target: 47
# when input is tensor([18, 47]) the target: 56
# when input is tensor([18, 47, 56]) the target: 57
# when input is tensor([18, 47, 56, 57]) the target: 58
# when input is tensor([18, 47, 56, 57, 58]) the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1]) the target: 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15]) the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47]) the target: 58

# %%
torch.manual_seed(1337)
batch_size = 4 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# targets:
# torch.Size([4, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39]])
# ----
# when input is [24] the target: 43
# when input is [24, 43] the target: 58
# when input is [24, 43, 58] the target: 5
# when input is [24, 43, 58, 5] the target: 57
# when input is [24, 43, 58, 5, 57] the target: 1
# when input is [24, 43, 58, 5, 57, 1] the target: 46
# when input is [24, 43, 58, 5, 57, 1, 46] the target: 43
# when input is [24, 43, 58, 5, 57, 1, 46, 43] the target: 39
# when input is [44] the target: 53
# when input is [44, 53] the target: 56
# when input is [44, 53, 56] the target: 1
# when input is [44, 53, 56, 1] the target: 58
# when input is [44, 53, 56, 1, 58] the target: 46
# when input is [44, 53, 56, 1, 58, 46] the target: 39
# when input is [44, 53, 56, 1, 58, 46, 39] the target: 58
# when input is [44, 53, 56, 1, 58, 46, 39, 58] the target: 1
# when input is [52] the target: 58
# when input is [52, 58] the target: 1
# when input is [52, 58, 1] the target: 58
# when input is [52, 58, 1, 58] the target: 46
# when input is [52, 58, 1, 58, 46] the target: 39
# when input is [52, 58, 1, 58, 46, 39] the target: 58
# when input is [52, 58, 1, 58, 46, 39, 58] the target: 1
# when input is [52, 58, 1, 58, 46, 39, 58, 1] the target: 46
# when input is [25] the target: 17
# when input is [25, 17] the target: 27
# when input is [25, 17, 27] the target: 10
# when input is [25, 17, 27, 10] the target: 0
# when input is [25, 17, 27, 10, 0] the target: 21
# when input is [25, 17, 27, 10, 0, 21] the target: 1
# when input is [25, 17, 27, 10, 0, 21, 1] the target: 54
# when input is [25, 17, 27, 10, 0, 21, 1, 54] the target: 39

# %%
print(xb) # our input to the transformer
# Out:
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([32, 65])
# tensor(4.8786, grad_fn=<NllLossBackward0>)
#
# Sr?qP-QWktXoL&jLDJgOLVz'RIoDqHdhsV&vLLxatjscMpwLERSPyao.qfzs$Ys$zF-w,;eEkzxjgCKFChs!iWW.ObzDnxA Ms$3

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for steps in range(100): # increase number of steps for good results...

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

print(loss.item())
# Out:
# 4.587916374206543

# %%
print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=500)[0].tolist()))
# Out:
# xiKi-RJ:CgqVuUa!U?qMH.uk!sCuMXvv!CJFfx;LgRyJknOEti.?I&-gPlLyulId?XlaInQ'q,lT$
# 3Q&sGlvHQ?mqSq-eON
# x?SP fUAfCAuCX:bOlgiRQWN:Mphaw
# tRLKuYXEaAXxrcq-gCUzeh3w!AcyaylgYWjmJM?Uzw:inaY,:C&OECW:vmGGJAn3onAuMgia!ms$Vb q-gCOcPcUhOnxJGUGSPJWT:.?ujmJFoiNL&A'DxY,prZ?qdT;hoo'dHooXXlxf'WkHK&u3Q?rqUi.kz;?Yx?C&u3Qbfzxlyh'Vl:zyxjKXgC?
# lv'QKFiBeviNxO'm!Upm$srm&TqViqiBD3HBP!juEOpmZJyF$Fwfy!PlvWPFC
# &WDdP!Ko,px
# x
# tREOE;AJ.BeXkylOVD3KHp$e?nD,.SFbWWI'ubcL!q-tU;aXmJ&uGXHxJXI&Z!gHRpajj;l.
# pTErIBjx;JKIgoCnLGXrJSP!AU-AcbczR?

# %% [markdown]
# ## The mathematical trick in self-attention

# %%
# toy example illustrating how matrix multiplication can be used for a "weighted aggregation"
torch.manual_seed(42)
a = torch.tril(torch.ones(3, 3))
a = a / torch.sum(a, 1, keepdim=True)
b = torch.randint(0,10,(3,2)).float()
c = a @ b
print('a=')
print(a)
print('--')
print('b=')
print(b)
print('--')
print('c=')
print(c)
# Out:
# a=
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000],
#         [0.3333, 0.3333, 0.3333]])
# --
# b=
# tensor([[2., 7.],
#         [6., 4.],
#         [6., 5.]])
# --
# c=
# tensor([[2.0000, 7.0000],
#         [4.0000, 5.5000],
#         [4.6667, 5.3333]])

# %%
# consider the following toy example:

torch.manual_seed(1337)
B,T,C = 4,8,2 # batch, time, channels
x = torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
# We want x[b,t] = mean_{i<=t} x[b,i]
xbow = torch.zeros((B,T,C))
for b in range(B):
    for t in range(T):
        xprev = x[b,:t+1] # (t,C)
        xbow[b,t] = torch.mean(xprev, 0)

# %%
# version 2: using matrix multiply for a weighted aggregation
wei = torch.tril(torch.ones(T, T))
wei = wei / wei.sum(1, keepdim=True)
xbow2 = wei @ x # (B, T, T) @ (B, T, C) ----> (B, T, C)
torch.allclose(xbow, xbow2)
# Out:
# False

# %%
# version 3: use Softmax
tril = torch.tril(torch.ones(T, T))
wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=-1)
xbow3 = wei @ x
torch.allclose(xbow, xbow3)
# Out:
# False

# %%
# version 4: self-attention!
torch.manual_seed(1337)
B,T,C = 4,8,32 # batch, time, channels
x = torch.randn(B,T,C)

# let's see a single Head perform self-attention
head_size = 16
key = nn.Linear(C, head_size, bias=False)
query = nn.Linear(C, head_size, bias=False)
value = nn.Linear(C, head_size, bias=False)
k = key(x)   # (B, T, 16)
q = query(x) # (B, T, 16)
wei =  q @ k.transpose(-2, -1) # (B, T, 16) @ (B, 16, T) ---> (B, T, T)

tril = torch.tril(torch.ones(T, T))
#wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=-1)

v = value(x)
out = wei @ v
#out = wei @ x

out.shape
# Out:
# torch.Size([4, 8, 16])

# %%
wei[0]
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1574, 0.8426, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2088, 0.1646, 0.6266, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5792, 0.1187, 0.1889, 0.1131, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0294, 0.1052, 0.0469, 0.0276, 0.7909, 0.0000, 0.0000, 0.0000],
#         [0.0176, 0.2689, 0.0215, 0.0089, 0.6812, 0.0019, 0.0000, 0.0000],
#         [0.1691, 0.4066, 0.0438, 0.0416, 0.1048, 0.2012, 0.0329, 0.0000],
#         [0.0210, 0.0843, 0.0555, 0.2297, 0.0573, 0.0709, 0.2423, 0.2391]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Notes:
# - Attention is a **communication mechanism**. Can be seen as nodes in a directed graph looking at each other and aggregating information with a weighted sum from all nodes that point to them, with data-dependent weights.
# - There is no notion of space. Attention simply acts over a set of vectors. This is why we need to positionally encode tokens.
# - Each example across batch dimension is of course processed completely independently and never "talk" to each other
# - In an "encoder" attention block just delete the single line that does masking with `tril`, allowing all tokens to communicate. This block here is called a "decoder" attention block because it has triangular masking, and is usually used in autoregressive settings, like language modeling.
# - "self-attention" just means that the keys and values are produced from the same source as queries. In "cross-attention", the queries still get produced from x, but the keys and values come from some other, external source (e.g. an encoder module)
# - "Scaled" attention additional divides `wei` by 1/sqrt(head_size). This makes it so when input Q,K are unit variance, wei will be unit variance too and Softmax will stay diffuse and not saturate too much. Illustration below

# %%
k = torch.randn(B,T,head_size)
q = torch.randn(B,T,head_size)
wei = q @ k.transpose(-2, -1) * head_size**-0.5

# %%
k.var()
# Out:
# tensor(1.0449)

# %%
q.var()
# Out:
# tensor(1.0700)

# %%
wei.var()
# Out:
# tensor(1.0918)

# %%
torch.softmax(torch.tensor([0.1, -0.2, 0.3, -0.2, 0.5]), dim=-1)
# Out:
# tensor([0.1925, 0.1426, 0.2351, 0.1426, 0.2872])

# %%
torch.softmax(torch.tensor([0.1, -0.2, 0.3, -0.2, 0.5])*8, dim=-1) # gets too peaky, converges to one-hot
# Out:
# tensor([0.0326, 0.0030, 0.1615, 0.0030, 0.8000])

# %%
class LayerNorm1d: # (used to be BatchNorm1d)

  def __init__(self, dim, eps=1e-5, momentum=0.1):
    self.eps = eps
    self.gamma = torch.ones(dim)
    self.beta = torch.zeros(dim)

  def __call__(self, x):
    # calculate the forward pass
    xmean = x.mean(1, keepdim=True) # batch mean
    xvar = x.var(1, keepdim=True) # batch variance
    xhat = (x - xmean) / torch.sqrt(xvar + self.eps) # normalize to unit variance
    self.out = self.gamma * xhat + self.beta
    return self.out

  def parameters(self):
    return [self.gamma, self.beta]

torch.manual_seed(1337)
module = LayerNorm1d(100)
x = torch.randn(32, 100) # batch size 32 of 100-dimensional vectors
x = module(x)
x.shape
# Out:
# torch.Size([32, 100])

# %%
x[:,0].mean(), x[:,0].std() # mean,std of one feature across all batch inputs
# Out:
# (tensor(0.1469), tensor(0.8803))

# %%
x[0,:].mean(), x[0,:].std() # mean,std of a single input from the batch, of its features
# Out:
# (tensor(-9.5367e-09), tensor(1.0000))

# %%
# French to English translation example:

# <--------- ENCODE ------------------><--------------- DECODE ----------------->
# les réseaux de neurones sont géniaux! <START> neural networks are awesome!<END>

# %% [markdown]
# ### Full finished code, for reference
#
# You may want to refer directly to the git repo instead though.

# %%
# !pip install mlflow==2.13.2 sagemaker-mlflow==0.1.0
# Out:
# Collecting mlflow==2.13.2
#   Downloading mlflow-2.13.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: sagemaker-mlflow==0.1.0 in /opt/conda/lib/python3.12/site-packages (0.1.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.16.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.1.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (7.1.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.1.44)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.4.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (6.10.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.8.2)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.10.3)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.34.1)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (24.2)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (2.2.3)
# Collecting protobuf<5,>=3.12.0 (from mlflow==2.13.2)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pyarrow<16,>=4.0.0 (from mlflow==2.13.2)
#   Downloading pyarrow-15.0.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pytz<2025 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (2024.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (6.0.2)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (2.32.4)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (2.0.41)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.12/site-packages (from mlflow==2.13.2) (3.1.6)
# Collecting gunicorn<23 (from mlflow==2.13.2)
#   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: boto3>=1.34 in /opt/conda/lib/python3.12/site-packages (from sagemaker-mlflow==0.1.0) (1.37.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/conda/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (4.14.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow==2.13.2) (1.26.19)
# Requirement already satisfied: blinker>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow==2.13.2) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow==2.13.2) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow==2.13.2) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow==2.13.2) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow==2.13.2) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.13.2) (5.0.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4->mlflow==2.13.2) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4->mlflow==2.13.2) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.12/site-packages (from graphene<4->mlflow==2.13.2) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.13.2) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.13.2) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow==2.13.2) (0.55b1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3->mlflow==2.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==2.13.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (2025.6.15)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn<2->mlflow==2.13.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn<2->mlflow==2.13.2) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.13.2) (3.2.3)
# Requirement already satisfied: botocore<1.38.0,>=1.37.1 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (0.11.3)
# Downloading mlflow-2.13.2-py3-none-any.whl (25.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 168.1 MB/s eta 0:00:00
# Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading pyarrow-15.0.2-cp312-cp312-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 180.0 MB/s eta 0:00:0000:01
# Installing collected packages: pyarrow, protobuf, gunicorn, mlflow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.1
#     Uninstalling pyarrow-19.0.1:
#       Successfully uninstalled pyarrow-19.0.1━━━ 0/4 [pyarrow]
#   Attempting uninstall: protobuf━━━━━━━━━━━━━━━━ 0/4 [pyarrow]
#     Found existing installation: protobuf 5.28.3 0/4 [pyarrow]
#     Uninstalling protobuf-5.28.3:━━━━━━━━━━━ 0/4 [pyarrow]
#       Successfully uninstalled protobuf-5.28.30m 0/4 [pyarrow]
#   Attempting uninstall: gunicorn━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [protobuf]
#     Found existing installation: gunicorn 23.0.0━━━━━━━━━━━━━━ 1/4 [protobuf]
#     Uninstalling gunicorn-23.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [protobuf]
#       Successfully uninstalled gunicorn-23.0.0━━━━━━━━━━━━━━━━ 1/4 [protobuf]
#   Attempting uninstall: mlflow90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [protobuf]
#     Found existing installation: mlflow 2.22.0━━━━━━━━━━━━━━━━ 1/4 [protobuf]
#     Uninstalling mlflow-2.22.0:━━━━━━━╺━━━━━━━━━ 3/4 [mlflow]
#       Successfully uninstalled mlflow-2.22.0━━━━━━━━━ 3/4 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [mlflow]2m3/4 [mlflow]
# Successfully installed gunicorn-22.0.0 mlflow-2.13.2 protobuf-4.25.8 pyarrow-15.0.2

# %%
import os
import torch
import torch.nn as nn
from torch.nn import functional as F
import mlflow

# 0) Configure tracking (must be BEFORE start_run)
mlflow.set_tracking_uri("arn:aws:sagemaker:us-west-2:759096226581:mlflow-tracking-server/llm-experimentation-mlflow-server")
mlflow.set_experiment("Tiny Shakespeare GPT 2")

with mlflow.start_run(run_name="gpt-from-scratch"):   # 1) Scope everything in the run

    # --- 2) Hyperparameters: define -> log immediately (they won’t change) ---
    batch_size = 16
    block_size = 32
    max_iters = 50000
    eval_interval = 100
    learning_rate = 1e-3
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    eval_iters = 200
    n_embd = 64
    n_head = 4
    n_layer = 4
    dropout = 0.0

    mlflow.log_params({
        "batch_size": batch_size,
        "block_size": block_size,
        "max_iters": max_iters,
        "eval_interval": eval_interval,
        "learning_rate": learning_rate,
        "eval_iters": eval_iters,
        "n_embd": n_embd,
        "n_head": n_head,
        "n_layer": n_layer,
        "dropout": dropout,
    })
    mlflow.set_tags({"device": device, "dataset": "input.txt"})

    torch.manual_seed(1337)

    # --- 3) Data: load -> you now know derived constants; log if useful for comparisons ---
    with open('input.txt', 'r', encoding='utf-8') as f:
        text = f.read()

    chars = sorted(list(set(text)))
    vocab_size = len(chars)
    stoi = { ch:i for i,ch in enumerate(chars) }
    itos = { i:ch for i,ch in enumerate(chars) }
    encode = lambda s: [stoi[c] for c in s]
    decode = lambda l: ''.join([itos[i] for i in l])

    data = torch.tensor(encode(text), dtype=torch.long)
    n = int(0.9*len(data))
    train_data = data[:n]
    val_data = data[n:]

    # log derived-but-stable run context
    mlflow.log_params({"vocab_size": vocab_size, "train_tokens": int(n), "val_tokens": int(len(data)-n)})

    # --- 4) Helpers (unchanged from your code) ---
    def get_batch(split):
        dataset = train_data if split == 'train' else val_data
        ix = torch.randint(len(dataset) - block_size, (batch_size,))
        x = torch.stack([dataset[i:i+block_size] for i in ix])
        y = torch.stack([dataset[i+1:i+block_size+1] for i in ix])
        x, y = x.to(device), y.to(device)
        return x, y

    @torch.no_grad()
    def estimate_loss():
        out = {}
        model.eval()
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters, device=device)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                logits, loss = model(X, Y)
                losses[k] = loss
            out[split] = losses.mean().item()
        model.train()
        return out

    class Head(nn.Module):
        def __init__(self, head_size):
            super().__init__()
            self.key = nn.Linear(n_embd, head_size, bias=False)
            self.query = nn.Linear(n_embd, head_size, bias=False)
            self.value = nn.Linear(n_embd, head_size, bias=False)
            self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
            self.dropout = nn.Dropout(dropout)
        def forward(self, x):
            B,T,C = x.shape
            k = self.key(x); q = self.query(x)
            wei = q @ k.transpose(-2,-1) * C**-0.5
            wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
            wei = F.softmax(wei, dim=-1)
            wei = self.dropout(wei)
            v = self.value(x)
            out = wei @ v
            return out

    class MultiHeadAttention(nn.Module):
        def __init__(self, num_heads, head_size):
            super().__init__()
            self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
            self.proj = nn.Linear(n_embd, n_embd)
            self.dropout = nn.Dropout(dropout)
        def forward(self, x):
            out = torch.cat([h(x) for h in self.heads], dim=-1)
            out = self.dropout(self.proj(out))
            return out

    class FeedFoward(nn.Module):
        def __init__(self, n_embd):
            super().__init__()
            self.net = nn.Sequential(
                nn.Linear(n_embd, 4 * n_embd),
                nn.ReLU(),
                nn.Linear(4 * n_embd, n_embd),
                nn.Dropout(dropout),
            )
        def forward(self, x):
            return self.net(x)

    class Block(nn.Module):
        def __init__(self, n_embd, n_head):
            super().__init__()
            head_size = n_embd // n_head
            self.sa = MultiHeadAttention(n_head, head_size)
            self.ffwd = FeedFoward(n_embd)
            self.ln1 = nn.LayerNorm(n_embd)
            self.ln2 = nn.LayerNorm(n_embd)
        def forward(self, x):
            x = x + self.sa(self.ln1(x))
            x = x + self.ffwd(self.ln2(x))
            return x

    class BigramLanguageModel(nn.Module):
        def __init__(self):
            super().__init__()
            self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
            self.position_embedding_table = nn.Embedding(block_size, n_embd)
            self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
            self.ln_f = nn.LayerNorm(n_embd)
            self.lm_head = nn.Linear(n_embd, vocab_size)
        def forward(self, idx, targets=None):
            B, T = idx.shape
            tok_emb = self.token_embedding_table(idx)
            pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
            x = tok_emb + pos_emb
            x = self.blocks(x)
            x = self.ln_f(x)
            logits = self.lm_head(x)
            loss = None
            if targets is not None:
                B, T, C = logits.shape
                logits = logits.view(B*T, C)
                targets = targets.view(B*T)
                loss = F.cross_entropy(logits, targets)
            return logits, loss
        def generate(self, idx, max_new_tokens):
            for _ in range(max_new_tokens):
                idx_cond = idx[:, -block_size:]
                logits, _ = self(idx_cond)
                logits = logits[:, -1, :]
                probs = F.softmax(logits, dim=-1)
                idx_next = torch.multinomial(probs, num_samples=1)
                idx = torch.cat((idx, idx_next), dim=1)
            return idx

    # --- 5) Model/opt: create -> log model size (derived, useful for comparisons) ---
    model = BigramLanguageModel().to(device)
    n_params_m = sum(p.numel() for p in model.parameters())/1e6
    print(round(n_params_m, 3), 'M parameters')
    mlflow.log_param("n_params_millions", round(n_params_m, 3))

    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    # --- 6) Training loop: compute -> log metrics at eval checkpoints (step=iter) ---
    for iter in range(max_iters):
        if iter % eval_interval == 0 or iter == max_iters - 1:
            losses = estimate_loss()
            print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
            mlflow.log_metrics({"loss/train": losses['train'], "loss/val": losses['val']}, step=iter)

        xb, yb = get_batch('train')
        logits, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        # optional: thin step-wise loss logging to every 10 steps
        if iter % 10 == 0:
            mlflow.log_metric("loss/step", float(loss.item()), step=iter)

    # --- 7) After training: generate sample text -> save -> log as artifact ---
    context = torch.zeros((1, 1), dtype=torch.long, device=device)
    sample_text = ''.join(decode(model.generate(context, max_new_tokens=2000)[0].tolist()))
    os.makedirs("artifacts", exist_ok=True)
    with open("artifacts/sample.txt", "w") as f:
        f.write(sample_text)
    mlflow.log_artifact("artifacts/sample.txt", artifact_path="samples")

    # --- 8) Log the model (final) ---
    import mlflow.pytorch
    mlflow.pytorch.log_model(model, artifact_path="model")   # (optionally add registered_model_name=...)
# Out:
# 2025/08/16 03:44:47 INFO mlflow.tracking.fluent: Experiment with name 'Tiny Shakespeare GPT 2' does not exist. Creating a new experiment.
# 0.21 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6568, val loss 2.6670
# step 200: train loss 2.5092, val loss 2.5060
# step 300: train loss 2.4194, val loss 2.4335
# step 400: train loss 2.3501, val loss 2.3562
# step 500: train loss 2.2966, val loss 2.3128
# step 600: train loss 2.2414, val loss 2.2502
# step 700: train loss 2.2054, val loss 2.2193
# step 800: train loss 2.1631, val loss 2.1865
# step 900: train loss 2.1236, val loss 2.1503
# step 1000: train loss 2.1021, val loss 2.1300
# step 1100: train loss 2.0693, val loss 2.1176
# step 1200: train loss 2.0383, val loss 2.0795
# step 1300: train loss 2.0245, val loss 2.0645
# step 1400: train loss 1.9928, val loss 2.0370
# step 1500: train loss 1.9697, val loss 2.0306
# step 1600: train loss 1.9636, val loss 2.0479
# step 1700: train loss 1.9403, val loss 2.0140
# step 1800: train loss 1.9072, val loss 1.9937
# step 1900: train loss 1.9094, val loss 1.9891
# step 2000: train loss 1.8834, val loss 1.9934
# step 2100: train loss 1.8696, val loss 1.9740
# step 2200: train loss 1.8593, val loss 1.9601
# step 2300: train loss 1.8542, val loss 1.9520
# step 2400: train loss 1.8403, val loss 1.9421
# step 2500: train loss 1.8150, val loss 1.9411
# step 2600: train loss 1.8256, val loss 1.9381
# step 2700: train loss 1.8122, val loss 1.9323
# step 2800: train loss 1.8022, val loss 1.9228
# step 2900: train loss 1.8021, val loss 1.9284
# step 3000: train loss 1.7951, val loss 1.9175
# step 3100: train loss 1.7670, val loss 1.9169
# step 3200: train loss 1.7526, val loss 1.9100
# step 3300: train loss 1.7539, val loss 1.9017
# step 3400: train loss 1.7537, val loss 1.8936
# step 3500: train loss 1.7378, val loss 1.8966
# step 3600: train loss 1.7243, val loss 1.8875
# step 3700: train loss 1.7254, val loss 1.8810
# step 3800: train loss 1.7202, val loss 1.8943
# step 3900: train loss 1.7191, val loss 1.8713
# step 4000: train loss 1.7175, val loss 1.8683
# step 4100: train loss 1.7123, val loss 1.8715
# step 4200: train loss 1.7081, val loss 1.8700
# step 4300: train loss 1.6994, val loss 1.8518
# step 4400: train loss 1.7075, val loss 1.8704
# step 4500: train loss 1.6884, val loss 1.8553
# step 4600: train loss 1.6829, val loss 1.8331
# step 4700: train loss 1.6848, val loss 1.8432
# step 4800: train loss 1.6677, val loss 1.8449
# step 4900: train loss 1.6728, val loss 1.8378
# step 5000: train loss 1.6656, val loss 1.8294
# step 5100: train loss 1.6706, val loss 1.8391
# step 5200: train loss 1.6573, val loss 1.8197
# step 5300: train loss 1.6629, val loss 1.8270
# step 5400: train loss 1.6558, val loss 1.8173
# step 5500: train loss 1.6514, val loss 1.8008
# step 5600: train loss 1.6614, val loss 1.8211
# step 5700: train loss 1.6571, val loss 1.8125
# step 5800: train loss 1.6406, val loss 1.8144
# step 5900: train loss 1.6450, val loss 1.8057
# step 6000: train loss 1.6405, val loss 1.8067
# step 6100: train loss 1.6388, val loss 1.7914
# step 6200: train loss 1.6428, val loss 1.7942
# step 6300: train loss 1.6270, val loss 1.7954
# step 6400: train loss 1.6274, val loss 1.8009
# step 6500: train loss 1.6263, val loss 1.7829
# step 6600: train loss 1.6257, val loss 1.7859
# step 6700: train loss 1.6209, val loss 1.8015
# step 6800: train loss 1.6247, val loss 1.7968
# step 6900: train loss 1.6143, val loss 1.7863
# step 7000: train loss 1.6124, val loss 1.7826
# step 7100: train loss 1.6164, val loss 1.7771
# step 7200: train loss 1.6100, val loss 1.7902
# step 7300: train loss 1.6123, val loss 1.7760
# step 7400: train loss 1.6129, val loss 1.7846
# step 7500: train loss 1.5982, val loss 1.7860
# step 7600: train loss 1.6040, val loss 1.7801
# step 7700: train loss 1.5950, val loss 1.7684
# step 7800: train loss 1.6030, val loss 1.7671
# step 7900: train loss 1.6020, val loss 1.7703
# step 8000: train loss 1.6012, val loss 1.7788
# step 8100: train loss 1.5971, val loss 1.7773
# step 8200: train loss 1.5989, val loss 1.7803
# step 8300: train loss 1.5888, val loss 1.7610
# step 8400: train loss 1.5929, val loss 1.7687
# step 8500: train loss 1.5961, val loss 1.7682
# step 8600: train loss 1.5906, val loss 1.7696
# step 8700: train loss 1.5864, val loss 1.7712
# step 8800: train loss 1.5703, val loss 1.7655
# step 8900: train loss 1.5862, val loss 1.7526
# step 9000: train loss 1.5832, val loss 1.7583
# step 9100: train loss 1.5732, val loss 1.7561
# step 9200: train loss 1.5866, val loss 1.7639
# step 9300: train loss 1.5714, val loss 1.7441
# step 9400: train loss 1.5784, val loss 1.7498
# step 9500: train loss 1.5788, val loss 1.7558
# step 9600: train loss 1.5730, val loss 1.7501
# step 9700: train loss 1.5703, val loss 1.7465
# step 9800: train loss 1.5614, val loss 1.7556
# step 9900: train loss 1.5645, val loss 1.7430
# step 10000: train loss 1.5637, val loss 1.7409
# step 10100: train loss 1.5694, val loss 1.7565
# step 10200: train loss 1.5595, val loss 1.7440
# step 10300: train loss 1.5557, val loss 1.7341
# step 10400: train loss 1.5631, val loss 1.7422
# step 10500: train loss 1.5633, val loss 1.7307
# step 10600: train loss 1.5637, val loss 1.7319
# step 10700: train loss 1.5637, val loss 1.7528
# step 10800: train loss 1.5580, val loss 1.7557
# step 10900: train loss 1.5461, val loss 1.7451
# step 11000: train loss 1.5519, val loss 1.7452
# step 11100: train loss 1.5448, val loss 1.7428
# step 11200: train loss 1.5531, val loss 1.7279
# step 11300: train loss 1.5518, val loss 1.7517
# step 11400: train loss 1.5586, val loss 1.7344
# step 11500: train loss 1.5524, val loss 1.7184
# step 11600: train loss 1.5504, val loss 1.7186
# step 11700: train loss 1.5421, val loss 1.7256
# step 11800: train loss 1.5384, val loss 1.7198
# step 11900: train loss 1.5479, val loss 1.7175
# step 12000: train loss 1.5367, val loss 1.7104
# step 12100: train loss 1.5340, val loss 1.7160
# step 12200: train loss 1.5356, val loss 1.7297
# step 12300: train loss 1.5310, val loss 1.7248
# step 12400: train loss 1.5458, val loss 1.7199
# step 12500: train loss 1.5465, val loss 1.7204
# step 12600: train loss 1.5483, val loss 1.7166
# step 12700: train loss 1.5484, val loss 1.7127
# step 12800: train loss 1.5406, val loss 1.7375
# step 12900: train loss 1.5402, val loss 1.7347
# step 13000: train loss 1.5353, val loss 1.7294
# step 13100: train loss 1.5330, val loss 1.7172
# step 13200: train loss 1.5350, val loss 1.7070
# step 13300: train loss 1.5291, val loss 1.7038
# step 13400: train loss 1.5369, val loss 1.7025
# step 13500: train loss 1.5299, val loss 1.7160
# step 13600: train loss 1.5314, val loss 1.7128
# step 13700: train loss 1.5233, val loss 1.7268
# step 13800: train loss 1.5294, val loss 1.7141
# step 13900: train loss 1.5368, val loss 1.7145
# step 14000: train loss 1.5236, val loss 1.7121
# step 14100: train loss 1.5269, val loss 1.7188
# step 14200: train loss 1.5263, val loss 1.7112
# step 14300: train loss 1.5229, val loss 1.7182
# step 14400: train loss 1.5143, val loss 1.6974
# step 14500: train loss 1.5248, val loss 1.6957
# step 14600: train loss 1.5284, val loss 1.7087
# step 14700: train loss 1.5341, val loss 1.7028
# step 14800: train loss 1.5340, val loss 1.7023
# step 14900: train loss 1.5285, val loss 1.7002
# step 15000: train loss 1.5214, val loss 1.7007
# step 15100: train loss 1.5216, val loss 1.6984
# step 15200: train loss 1.5161, val loss 1.6912
# step 15300: train loss 1.5151, val loss 1.6883
# step 15400: train loss 1.5274, val loss 1.6925
# step 15500: train loss 1.5136, val loss 1.6973
# step 15600: train loss 1.5225, val loss 1.6867
# step 15700: train loss 1.5230, val loss 1.7004
# step 15800: train loss 1.5160, val loss 1.6955
# step 15900: train loss 1.5161, val loss 1.7056
# step 16000: train loss 1.5060, val loss 1.6982
# step 16100: train loss 1.5135, val loss 1.6936
# step 16200: train loss 1.5130, val loss 1.7003
# step 16300: train loss 1.5044, val loss 1.6984
# step 16400: train loss 1.5170, val loss 1.6888
# step 16500: train loss 1.5036, val loss 1.7005
# step 16600: train loss 1.5060, val loss 1.7040
# step 16700: train loss 1.5059, val loss 1.6927
# step 16800: train loss 1.5083, val loss 1.6993
# step 16900: train loss 1.5166, val loss 1.7015
# step 17000: train loss 1.5174, val loss 1.7052
# step 17100: train loss 1.5142, val loss 1.7033
# step 17200: train loss 1.5189, val loss 1.6929
# step 17300: train loss 1.5052, val loss 1.6787
# step 17400: train loss 1.5139, val loss 1.6980
# step 17500: train loss 1.5110, val loss 1.6796
# step 17600: train loss 1.5013, val loss 1.6821
# step 17700: train loss 1.5045, val loss 1.7030
# step 17800: train loss 1.5003, val loss 1.6701
# step 17900: train loss 1.5141, val loss 1.7073
# step 18000: train loss 1.4991, val loss 1.6795
# step 18100: train loss 1.4917, val loss 1.6831
# step 18200: train loss 1.5008, val loss 1.7018
# step 18300: train loss 1.5042, val loss 1.6711
# step 18400: train loss 1.5033, val loss 1.6944
# step 18500: train loss 1.5006, val loss 1.6779
# step 18600: train loss 1.4939, val loss 1.6833
# step 18700: train loss 1.5042, val loss 1.7026
# step 18800: train loss 1.5005, val loss 1.6956
# step 18900: train loss 1.5077, val loss 1.6819
# step 19000: train loss 1.4978, val loss 1.6808
# step 19100: train loss 1.4925, val loss 1.6725
# step 19200: train loss 1.5080, val loss 1.6669
# step 19300: train loss 1.5032, val loss 1.6712
# step 19400: train loss 1.4971, val loss 1.6937
# step 19500: train loss 1.5022, val loss 1.6954
# step 19600: train loss 1.5001, val loss 1.6768
# step 19700: train loss 1.4968, val loss 1.6833
# step 19800: train loss 1.4952, val loss 1.6814
# step 19900: train loss 1.4944, val loss 1.6817
# step 20000: train loss 1.4787, val loss 1.6701
# step 20100: train loss 1.4891, val loss 1.6862
# step 20200: train loss 1.4919, val loss 1.6772
# step 20300: train loss 1.4887, val loss 1.6726
# step 20400: train loss 1.4898, val loss 1.6692
# step 20500: train loss 1.4907, val loss 1.6690
# step 20600: train loss 1.4953, val loss 1.6769
# step 20700: train loss 1.4798, val loss 1.6717
# step 20800: train loss 1.4869, val loss 1.6851
# step 20900: train loss 1.4916, val loss 1.6733
# step 21000: train loss 1.4929, val loss 1.6858
# step 21100: train loss 1.4928, val loss 1.6633
# step 21200: train loss 1.4884, val loss 1.6743
# step 21300: train loss 1.4939, val loss 1.6966
# step 21400: train loss 1.4779, val loss 1.6760
# step 21500: train loss 1.4873, val loss 1.6806
# step 21600: train loss 1.4885, val loss 1.6704
# step 21700: train loss 1.4731, val loss 1.6770
# step 21800: train loss 1.4765, val loss 1.6719
# step 21900: train loss 1.4835, val loss 1.6787
# step 22000: train loss 1.4831, val loss 1.6809
# step 22100: train loss 1.4880, val loss 1.6969
# step 22200: train loss 1.4769, val loss 1.6797
# step 22300: train loss 1.4815, val loss 1.6681
# step 22400: train loss 1.4897, val loss 1.6694
# step 22500: train loss 1.4863, val loss 1.6732
# step 22600: train loss 1.4843, val loss 1.6838
# step 22700: train loss 1.4917, val loss 1.6874
# step 22800: train loss 1.4863, val loss 1.6710
# step 22900: train loss 1.4745, val loss 1.6810
# step 23000: train loss 1.4863, val loss 1.6731
# step 23100: train loss 1.4790, val loss 1.6794
# step 23200: train loss 1.4688, val loss 1.6638
# step 23300: train loss 1.4844, val loss 1.6680
# step 23400: train loss 1.4822, val loss 1.6638
# step 23500: train loss 1.4824, val loss 1.6825
# step 23600: train loss 1.4845, val loss 1.6768
# step 23700: train loss 1.4764, val loss 1.6866
# step 23800: train loss 1.4625, val loss 1.6784
# step 23900: train loss 1.4852, val loss 1.6811
# step 24000: train loss 1.4706, val loss 1.6648
# step 24100: train loss 1.4763, val loss 1.6670
# step 24200: train loss 1.4682, val loss 1.6638
# step 24300: train loss 1.4652, val loss 1.6659
# step 24400: train loss 1.4783, val loss 1.6669
# step 24500: train loss 1.4707, val loss 1.6694
# step 24600: train loss 1.4794, val loss 1.6691
# step 24700: train loss 1.4656, val loss 1.6790
# step 24800: train loss 1.4710, val loss 1.6561
# step 24900: train loss 1.4726, val loss 1.6795
# step 25000: train loss 1.4698, val loss 1.6733
# step 25100: train loss 1.4754, val loss 1.6630
# step 25200: train loss 1.4650, val loss 1.6806
# step 25300: train loss 1.4573, val loss 1.6747
# step 25400: train loss 1.4722, val loss 1.6747
# step 25500: train loss 1.4680, val loss 1.6755
# step 25600: train loss 1.4668, val loss 1.6723
# step 25700: train loss 1.4645, val loss 1.6676
# step 25800: train loss 1.4731, val loss 1.6725
# step 25900: train loss 1.4503, val loss 1.6621
# step 26000: train loss 1.4619, val loss 1.6673
# step 26100: train loss 1.4778, val loss 1.6678
# step 26200: train loss 1.4582, val loss 1.6632
# step 26300: train loss 1.4674, val loss 1.6718
# step 26400: train loss 1.4714, val loss 1.6800
# step 26500: train loss 1.4686, val loss 1.6514
# step 26600: train loss 1.4678, val loss 1.6628
# step 26700: train loss 1.4590, val loss 1.6621
# step 26800: train loss 1.4622, val loss 1.6479
# step 26900: train loss 1.4591, val loss 1.6615
# step 27000: train loss 1.4629, val loss 1.6603
# step 27100: train loss 1.4579, val loss 1.6533
# step 27200: train loss 1.4703, val loss 1.6576
# step 27300: train loss 1.4649, val loss 1.6693
# step 27400: train loss 1.4703, val loss 1.6658
# step 27500: train loss 1.4743, val loss 1.6552
# step 27600: train loss 1.4596, val loss 1.6549
# step 27700: train loss 1.4617, val loss 1.6563
# step 27800: train loss 1.4604, val loss 1.6536
# step 27900: train loss 1.4586, val loss 1.6648
# step 28000: train loss 1.4536, val loss 1.6581
# step 28100: train loss 1.4788, val loss 1.6543
# step 28200: train loss 1.4627, val loss 1.6468
# step 28300: train loss 1.4606, val loss 1.6521
# step 28400: train loss 1.4517, val loss 1.6512
# step 28500: train loss 1.4558, val loss 1.6614
# step 28600: train loss 1.4621, val loss 1.6608
# step 28700: train loss 1.4510, val loss 1.6564
# step 28800: train loss 1.4592, val loss 1.6558
# step 28900: train loss 1.4570, val loss 1.6455
# step 29000: train loss 1.4681, val loss 1.6516
# step 29100: train loss 1.4502, val loss 1.6651
# step 29200: train loss 1.4604, val loss 1.6471
# step 29300: train loss 1.4546, val loss 1.6438
# step 29400: train loss 1.4593, val loss 1.6534
# step 29500: train loss 1.4542, val loss 1.6387
# step 29600: train loss 1.4538, val loss 1.6438
# step 29700: train loss 1.4617, val loss 1.6504
# step 29800: train loss 1.4669, val loss 1.6501
# step 29900: train loss 1.4618, val loss 1.6454
# step 30000: train loss 1.4518, val loss 1.6589
# step 30100: train loss 1.4538, val loss 1.6501
# step 30200: train loss 1.4478, val loss 1.6547
# step 30300: train loss 1.4590, val loss 1.6572
# step 30400: train loss 1.4652, val loss 1.6654
# step 30500: train loss 1.4693, val loss 1.6615
# step 30600: train loss 1.4621, val loss 1.6516
# step 30700: train loss 1.4504, val loss 1.6378
# step 30800: train loss 1.4544, val loss 1.6506
# step 30900: train loss 1.4595, val loss 1.6544
# step 31000: train loss 1.4503, val loss 1.6498
# step 31100: train loss 1.4458, val loss 1.6666
# step 31200: train loss 1.4553, val loss 1.6445
# step 31300: train loss 1.4524, val loss 1.6458
# step 31400: train loss 1.4583, val loss 1.6545
# step 31500: train loss 1.4616, val loss 1.6630
# step 31600: train loss 1.4525, val loss 1.6660
# step 31700: train loss 1.4472, val loss 1.6564
# step 31800: train loss 1.4493, val loss 1.6590
# step 31900: train loss 1.4467, val loss 1.6511
# step 32000: train loss 1.4389, val loss 1.6511
# step 32100: train loss 1.4456, val loss 1.6571
# step 32200: train loss 1.4565, val loss 1.6567
# step 32300: train loss 1.4527, val loss 1.6590
# step 32400: train loss 1.4478, val loss 1.6504
# step 32500: train loss 1.4483, val loss 1.6539
# step 32600: train loss 1.4529, val loss 1.6430
# step 32700: train loss 1.4607, val loss 1.6509
# step 32800: train loss 1.4482, val loss 1.6574
# step 32900: train loss 1.4443, val loss 1.6518
# step 33000: train loss 1.4488, val loss 1.6427
# step 33100: train loss 1.4528, val loss 1.6440
# step 33200: train loss 1.4588, val loss 1.6607
# step 33300: train loss 1.4614, val loss 1.6384
# step 33400: train loss 1.4575, val loss 1.6569
# step 33500: train loss 1.4554, val loss 1.6562
# step 33600: train loss 1.4421, val loss 1.6441
# step 33700: train loss 1.4494, val loss 1.6459
# step 33800: train loss 1.4502, val loss 1.6531
# step 33900: train loss 1.4411, val loss 1.6431
# step 34000: train loss 1.4497, val loss 1.6527
# step 34100: train loss 1.4507, val loss 1.6475
# step 34200: train loss 1.4384, val loss 1.6502
# step 34300: train loss 1.4497, val loss 1.6466
# step 34400: train loss 1.4434, val loss 1.6470
# step 34500: train loss 1.4432, val loss 1.6381
# step 34600: train loss 1.4417, val loss 1.6520
# step 34700: train loss 1.4509, val loss 1.6604
# step 34800: train loss 1.4493, val loss 1.6580
# step 34900: train loss 1.4564, val loss 1.6500
# step 35000: train loss 1.4470, val loss 1.6391
# step 35100: train loss 1.4372, val loss 1.6385
# step 35200: train loss 1.4481, val loss 1.6410
# step 35300: train loss 1.4389, val loss 1.6509
# step 35400: train loss 1.4449, val loss 1.6504
# step 35500: train loss 1.4379, val loss 1.6422
# step 35600: train loss 1.4372, val loss 1.6485
# step 35700: train loss 1.4342, val loss 1.6565
# step 35800: train loss 1.4431, val loss 1.6295
# step 35900: train loss 1.4504, val loss 1.6442
# step 36000: train loss 1.4353, val loss 1.6436
# step 36100: train loss 1.4359, val loss 1.6477
# step 36200: train loss 1.4383, val loss 1.6353
# step 36300: train loss 1.4322, val loss 1.6447
# step 36400: train loss 1.4424, val loss 1.6441
# step 36500: train loss 1.4442, val loss 1.6382
# step 36600: train loss 1.4415, val loss 1.6363
# step 36700: train loss 1.4314, val loss 1.6374
# step 36800: train loss 1.4410, val loss 1.6507
# step 36900: train loss 1.4421, val loss 1.6415
# step 37000: train loss 1.4498, val loss 1.6488
# step 37100: train loss 1.4364, val loss 1.6421
# step 37200: train loss 1.4386, val loss 1.6483
# step 37300: train loss 1.4430, val loss 1.6625
# step 37400: train loss 1.4478, val loss 1.6521
# step 37500: train loss 1.4416, val loss 1.6502
# step 37600: train loss 1.4331, val loss 1.6448
# step 37700: train loss 1.4383, val loss 1.6461
# step 37800: train loss 1.4341, val loss 1.6706
# step 37900: train loss 1.4503, val loss 1.6561
# step 38000: train loss 1.4380, val loss 1.6502
# step 38100: train loss 1.4352, val loss 1.6434
# step 38200: train loss 1.4440, val loss 1.6592
# step 38300: train loss 1.4435, val loss 1.6391
# step 38400: train loss 1.4339, val loss 1.6474
# step 38500: train loss 1.4478, val loss 1.6508
# step 38600: train loss 1.4362, val loss 1.6354
# step 38700: train loss 1.4449, val loss 1.6289
# step 38800: train loss 1.4313, val loss 1.6361
# step 38900: train loss 1.4374, val loss 1.6427
# step 39000: train loss 1.4306, val loss 1.6374
# step 39100: train loss 1.4281, val loss 1.6360
# step 39200: train loss 1.4285, val loss 1.6498
# step 39300: train loss 1.4340, val loss 1.6284
# step 39400: train loss 1.4364, val loss 1.6456
# step 39500: train loss 1.4259, val loss 1.6360
# step 39600: train loss 1.4337, val loss 1.6487
# step 39700: train loss 1.4306, val loss 1.6473
# step 39800: train loss 1.4301, val loss 1.6292
# step 39900: train loss 1.4339, val loss 1.6436
# step 40000: train loss 1.4370, val loss 1.6218
# step 40100: train loss 1.4359, val loss 1.6312
# step 40200: train loss 1.4283, val loss 1.6474
# step 40300: train loss 1.4429, val loss 1.6488
# step 40400: train loss 1.4412, val loss 1.6523
# step 40500: train loss 1.4300, val loss 1.6437
# step 40600: train loss 1.4427, val loss 1.6559
# step 40700: train loss 1.4374, val loss 1.6455
# step 40800: train loss 1.4392, val loss 1.6385
# step 40900: train loss 1.4362, val loss 1.6430
# step 41000: train loss 1.4255, val loss 1.6442
# step 41100: train loss 1.4422, val loss 1.6370
# step 41200: train loss 1.4268, val loss 1.6347
# step 41300: train loss 1.4194, val loss 1.6415
# step 41400: train loss 1.4367, val loss 1.6514
# step 41500: train loss 1.4369, val loss 1.6486
# step 41600: train loss 1.4372, val loss 1.6452
# step 41700: train loss 1.4370, val loss 1.6340
# step 41800: train loss 1.4273, val loss 1.6482
# step 41900: train loss 1.4356, val loss 1.6420
# step 42000: train loss 1.4361, val loss 1.6516
# step 42100: train loss 1.4264, val loss 1.6385
# step 42200: train loss 1.4355, val loss 1.6420
# step 42300: train loss 1.4308, val loss 1.6447
# step 42400: train loss 1.4277, val loss 1.6433
# step 42500: train loss 1.4228, val loss 1.6195
# step 42600: train loss 1.4327, val loss 1.6445
# step 42700: train loss 1.4259, val loss 1.6418
# step 42800: train loss 1.4309, val loss 1.6446
# step 42900: train loss 1.4376, val loss 1.6384
# step 43000: train loss 1.4248, val loss 1.6410
# step 43100: train loss 1.4209, val loss 1.6382
# step 43200: train loss 1.4352, val loss 1.6319
# step 43300: train loss 1.4271, val loss 1.6398
# step 43400: train loss 1.4335, val loss 1.6428
# step 43500: train loss 1.4258, val loss 1.6306
# step 43600: train loss 1.4143, val loss 1.6252
# step 43700: train loss 1.4333, val loss 1.6450
# step 43800: train loss 1.4341, val loss 1.6404
# step 43900: train loss 1.4387, val loss 1.6386
# step 44000: train loss 1.4222, val loss 1.6414
# step 44100: train loss 1.4324, val loss 1.6251
# step 44200: train loss 1.4345, val loss 1.6403
# step 44300: train loss 1.4376, val loss 1.6575
# step 44400: train loss 1.4260, val loss 1.6285
# step 44500: train loss 1.4194, val loss 1.6090
# step 44600: train loss 1.4206, val loss 1.6248
# step 44700: train loss 1.4334, val loss 1.6420
# step 44800: train loss 1.4292, val loss 1.6251
# step 44900: train loss 1.4209, val loss 1.6207
# step 45000: train loss 1.4225, val loss 1.6313
# step 45100: train loss 1.4287, val loss 1.6347
# step 45200: train loss 1.4303, val loss 1.6440
# step 45300: train loss 1.4300, val loss 1.6387
# step 45400: train loss 1.4218, val loss 1.6325
# step 45500: train loss 1.4209, val loss 1.6421
# step 45600: train loss 1.4314, val loss 1.6502
# step 45700: train loss 1.4287, val loss 1.6444
# step 45800: train loss 1.4209, val loss 1.6323
# step 45900: train loss 1.4265, val loss 1.6320
# step 46000: train loss 1.4263, val loss 1.6279
# step 46100: train loss 1.4254, val loss 1.6290
# step 46200: train loss 1.4357, val loss 1.6253
# step 46300: train loss 1.4263, val loss 1.6255
# step 46400: train loss 1.4289, val loss 1.6511
# step 46500: train loss 1.4288, val loss 1.6461
# step 46600: train loss 1.4323, val loss 1.6411
# step 46700: train loss 1.4190, val loss 1.6430
# step 46800: train loss 1.4271, val loss 1.6281
# step 46900: train loss 1.4301, val loss 1.6344
# step 47000: train loss 1.4193, val loss 1.6437
# step 47100: train loss 1.4226, val loss 1.6282
# step 47200: train loss 1.4340, val loss 1.6325
# step 47300: train loss 1.4220, val loss 1.6302
# step 47400: train loss 1.4308, val loss 1.6393
# step 47500: train loss 1.4265, val loss 1.6398
# step 47600: train loss 1.4233, val loss 1.6324
# step 47700: train loss 1.4198, val loss 1.6383
# step 47800: train loss 1.4196, val loss 1.6455
# step 47900: train loss 1.4337, val loss 1.6560
# step 48000: train loss 1.4288, val loss 1.6452
# step 48100: train loss 1.4337, val loss 1.6297
# step 48200: train loss 1.4269, val loss 1.6475
# step 48300: train loss 1.4198, val loss 1.6359
# step 48400: train loss 1.4184, val loss 1.6349
# step 48500: train loss 1.4184, val loss 1.6301
# step 48600: train loss 1.4200, val loss 1.6348
# step 48700: train loss 1.4125, val loss 1.6267
# step 48800: train loss 1.4259, val loss 1.6378
# step 48900: train loss 1.4198, val loss 1.6479
# step 49000: train loss 1.4197, val loss 1.6480
# step 49100: train loss 1.4208, val loss 1.6396
# step 49200: train loss 1.4227, val loss 1.6544
# step 49300: train loss 1.4290, val loss 1.6566
# step 49400: train loss 1.4196, val loss 1.6270
# step 49500: train loss 1.4225, val loss 1.6209
# step 49600: train loss 1.4188, val loss 1.6535
# step 49700: train loss 1.4152, val loss 1.6581
# step 49800: train loss 1.4172, val loss 1.6294
# step 49900: train loss 1.4093, val loss 1.6288
# step 49999: train loss 1.4188, val loss 1.6425
# 2025/08/16 04:20:52 WARNING mlflow.utils.requirements_utils: Found triton version (3.2.0+git576374f8) contains a local version label (+git576374f8). MLflow logged a pip requirement for this package as 'triton==3.2.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
